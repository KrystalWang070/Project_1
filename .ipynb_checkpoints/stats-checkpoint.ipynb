# %%
import pandas as pd
from scipy.stats import linregress
from matplotlib import pyplot as plt
fp = "langs_by_county.csv"
csv_df = pd.read_csv(fp)
csv_df.sort_values('population')
# Out:
#       fips                  county  state code  county code  population  \
# 2     4017       Navajo County, AZ           4           17      107322
# 100  35045     San Juan County, NM          35           45      126503
# 49   15009         Maui County, HI          15            9      160202
# 47   15001       Hawaii County, HI          15            1      190821
# 25    6113         Yolo County, CA           6          113      204593
# ..     ...                     ...         ...          ...         ...
# 15    6073    San Diego County, CA           6           73     3211252
# 1     4013     Maricopa County, AZ           4           13     4009412
# 139  48201       Harris County, TX          48          201     4336853
# 50   17031         Cook County, IL          17           31     5240700
# 8     6037  Los Angeles County, CA           6           37    10017068
#
#      no_french  pct_french  no_spanish  pct_spanish  no_chinese  pct_chinese
# 2           85    0.079201        5885     5.483498           0     0.000000
# 100        205    0.162051       12025     9.505703          45     0.035572
# 49         740    0.461917        2750     1.716583         210     0.131085
# 47         625    0.327532        4440     2.326788         250     0.131013
# 25         605    0.295709       40085    19.592557        3385     1.654504
# ..         ...         ...         ...          ...         ...          ...
# 15        9135    0.284468      725295    22.586051       27495     0.856208
# 1        10680    0.266373      733630    18.297696       13750     0.342943
# 139      15510    0.357633     1313020    30.275871       28485     0.656813
# 50       18265    0.348522      991495    18.919133       39185     0.747705
# 8        38235    0.381699     3653910    36.476841      174385     1.740879
#
# [155 rows x 11 columns]

# %%
#Floor division prevents millions of data points in calculating line
pop = csv_df['population']
spanish = csv_df['pct_spanish']
french = csv_df['pct_french']
chinese = csv_df['pct_chinese']
m,b, _,_,_ = linregress(pop,spanish)
min_pop = min(pop)
max_pop = max(pop)
#line = [m*x+b for x in range(min_pop,max_pop)]

# %%
import matplotlib.lines as mlines

min_pct = m*min_pop+b
max_pct = m*max_pop+b

l = mlines.Line2D([min_pop,max_pop],[min_pct,max_pct],color='orange')
plt.scatter(pop,spanish)
#plt.plot(line, color='orange')
ax = plt.gca()
ax.add_line(l)

# %%
min(pop)
# Out:
# 10732

# %%
state_df = csv_df.groupby('state code').sum()
#Floor division prevents millions of data points in calculating line
state_pop = list(state_df['population'])
state_spanish = list(state_df['no_spanish']/state_pop*100)
state_french = state_df['pct_french']
state_chinese = state_df['pct_chinese']
m,b,_,_,_ = linregress(state_pop,state_spanish)
min_pop = min(state_pop)
max_pop = max(state_pop)
#line = [m*x+b for x in range(min_pop,max_pop)]
print(min_pop,max_pop)
# Out:
# 300950 34550768

# %%
min_pct = m*min_pop+b
max_pct = m*max_pop+b

l = mlines.Line2D([min_pop,max_pop],[min_pct,max_pct],color='orange')
plt.scatter(state_pop,state_spanish)
plt.ylim(0,40)
ax = plt.gca()
ax.add_line(l)

# %%
state_codes = state_df.index
plt.scatter(state_codes,state_spanish)
m,b,_,_,_=linregress(state_df.index,state_spanish)

min_state = state_codes[0]
max_state = state_codes[-1]
min_pct = m*min_state+b
max_pct = m*max_state+b
l = mlines.Line2D([min_state,max_state],[min_pct,max_pct],color='orange')

#plt.ylim(0,40)
ax = plt.gca()
ax.add_line(l)

# %%
state_df
# Out:
#               fips  county code  population  no_french  pct_french  \
# state code
# 2             2020           20      300950       1035    0.343911
# 4            12049           49     5113288      13995    0.669691
# 6           133464         1464    34550768     114500    7.234520
# 8            24077           77     1911609       7640    1.205154
# 9            27013           13     2700463      22570    2.502310
# 10           10003            3      549684       2545    0.462993
# 11           11001            1      646449       8360    1.293219
# 12          108574          574    11160696      72955    5.557083
# 13           52412          412     3274127      22475    2.736379
# 15           45013           13     1334452       4095    1.067049
# 17           85457          457     8082317      26030    1.424980
# 18           18097           97      928281       3765    0.405588
# 19           19153          153      451677       1005    0.222504
# 20           20091           91      566933       1690    0.298095
# 21           21111          111      756832       2300    0.303898
# 22           22051           51      434767       2785    0.640573
# 24          144609          609     4212200      44595    5.618373
# 25          200140          140     6089777      56440    7.013225
# 26          104548          548     4215922      13520    1.367127
# 27           81213          213     2134001       9140    1.221964
# 29           29189          189     1001444       3265    0.326029
# 32           64034           34     2461599       7215    0.585067
# 33           33011           11      403985       9465    2.342909
# 34          476276          276     7911058      33325    5.700778
# 35           70046           46      800724       2135    0.448308
# 36          504870          870    15367822     116165    9.256166
# 37          111383          383     2471876      12310    1.481844
# 39          117145          145     3279937      12680    1.192296
# 40           40109          109      755245       1240    0.164185
# 41           82118          118     1321131       4855    0.714640
# 42          294357          357     5825085      24635    2.871542
# 44           44007            7      628600       7815    1.243239
# 47           94194          194     1598067       4190    0.512727
# 48          385598         1598    13903231      43395    2.567514
# 49           49035           35     1079721       2590    0.239877
# 51          307229         1229     2911179      15895    3.200658
# 53          212158          158     4053922      16880    1.304655
# 55          110104          104     1465962       4470    0.655141
#
#             no_spanish  pct_spanish  no_chinese  pct_chinese
# state code
# 2                12635     4.198372         740     0.245888
# 4               956630    45.567770       18375     0.807042
# 6              9257590   508.268807      565205    33.660606
# 8               224135    35.172157        5880     0.929825
# 9               330045    36.570095       15500     1.723146
# 10               37545     6.830288        4535     0.825019
# 11               44455     6.876799        2665     0.412252
# 12             2892445   181.003664       28660     2.162096
# 13              331295    40.649716       22050     2.643370
# 15               24170     5.769982       17250     1.969389
# 17             1394370    79.281313       56370     2.970012
# 18               70390     7.582833        3110     0.335028
# 19               24515     5.427551        1595     0.353128
# 20               25805     4.551684        2800     0.493886
# 21               26970     3.563539        1715     0.226602
# 22               43015     9.893805        1720     0.395614
# 24              325855    40.546104       43620     6.006009
# 25              488730    66.624625       68315     7.569863
# 26              112800     9.727928       19995     2.660776
# 27              105620    14.291007       11050     1.533654
# 29               20480     2.045047        5695     0.568679
# 32              484345    35.823038       17225     1.162968
# 33               15865     3.927126        1620     0.401005
# 34             1212030   208.343830       76390    13.549101
# 35              172945    33.373248        1595     0.265467
# 36             2577405   190.211814      323665    19.771528
# 37              194910    22.527621       11520     1.350507
# 39              102320     9.076050       16560     1.418667
# 40               81475    10.787890        2340     0.309833
# 41              119665    18.696503       11120     1.685322
# 42              270215    29.602247       42645     4.450289
# 44               99930    15.897232        3115     0.495546
# 47               94625    12.341428        4545     0.574118
# 48             3553330   172.163635       84970     6.504796
# 49              122665    11.360805        4555     0.421868
# 51              298830    57.982487       26050     4.338913
# 53              227225    21.340196       46675     3.173789
# 55              111730    13.856925        6790     1.115587
