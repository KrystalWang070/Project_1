# %%
# %matplotlib widget

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#read percentage file
bar_df = pd.read_csv("langs_by_county.csv") 
bar_df.head()
# Out:
#    fips                      county  state code  county code  population  \
# 0  2020  Anchorage Municipality, AK           2           20      300950
# 1  4013         Maricopa County, AZ           4           13     4009412
# 2  4017           Navajo County, AZ           4           17      107322
# 3  4019             Pima County, AZ           4           19      996554
# 4  6001          Alameda County, CA           6            1     1578891
#
#    no_french  pct_french  no_spanish  pct_spanish  no_chinese  pct_chinese
# 0       1035    0.343911       12635     4.198372         740     0.245888
# 1      10680    0.266373      733630    18.297696       13750     0.342943
# 2         85    0.079201        5885     5.483498           0     0.000000
# 3       3230    0.324117      217115    21.786577        4625     0.464099
# 4       6915    0.437966      241150    15.273379       69165     4.380606

# %%
# Set x axis and tick locations
x_axis = np.arange(len(bar_df))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(40,3))
plt.bar(x_axis, bar_df["pct_french"], color='r', alpha=1, align="center")
plt.xticks(tick_locations, bar_df["county"], rotation="vertical")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to  previous…
# ([<matplotlib.axis.XTick at 0x12fdc4490>,
# ...
#  <a list of 155 Text xticklabel objects>)

# %%
plt.xlim(-1, len(x_axis))
plt.ylim(0, max(bar_df["pct_french"])+5)
# Out:
# (0, 7.342908771365273)

# %%
# Set a Title and labels
plt.title("Percentage of Households Speaking French per State")
plt.xlabel("State")
plt.ylabel("Percentage of Households Speaking French")
# Out:
# Text(175.694,0.5,'Percentage of Households Speaking French')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("bar_pct_french.png")
plt.show()
