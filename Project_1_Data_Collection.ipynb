# %% [markdown]
# # Collecting and Cleaning US Census Data for Various Linguistic Groups#
#
# The purpose of this notebook is to collect two blocks of data from the US Census API Server:
#
# * The geographic distribution for three foreign languages of interest - Spanish, French, and Chinese(1)(2)
# * Data on the language groups spoken in Cook County(3)
#
# _(1)We originally selected six languages - Spanish, French, Chinese, Hindi, Polish, and Arabic. We focused in on three of them because it is sufficiently illustrative of the Census API's abilities and because there was some unclear directions in the census API documentation and we only figured out how to access Hindi, Polish, and Arabic a few days before the presentation._
#
# _(2)The Census language survey lists "Chinese" as well as Chinese dialects such as Cantonese and Mandarin; the documentation appears to suggest that this is due to the response of the participants. Therefore it appears that Chinese, Cantonese, and Mandarin, for example, are not overlapping groups, they are each separate populations._
#
# _(3)The Census collects information on 380 languages. Not all languages are accessible using the basic API query format and for many languages the number of speakers in Cook County is estimated at 'none'. Many languages are not returned by the API request at all. We are at about 150 surveyed languages for cook county._

# %%
#Import Functions - all functions in notebook. 

import pandas as pd
import numpy as np
import requests
import json
import csv
from apikey import api_key

# %% [markdown]
# ## Collecting and cleaning US Census Data for the three target languages nationwide
#
# * This section of the notebook covers the first research question - data about Spanish, Chinese, and French
#
# _Note: The Census does not collect these data for all US counties, only for a number of key metropolitan areas. There are other tiers of analysis - state and nationwide estimates - but we chose to focus on metro areas only._

# %%
#These are the language codes used by the Census in their API requests. They're from a PDF downloaded from the Census website so there's no way I'm aware of to do this automatically. 

spanish = 625
chinese = 708
french = 620

#This is the census API URL for a search covering all counties in the survey
#It is returning the population estimate, the name of the language, and the name of the geographic area. 

url = "https://api.census.gov/data/2013/language?get=EST,LANLABEL,NAME&for=county:*&LAN="

#These are the API queries for the three languages that return results from the Census

query_spanish = f"{url}{spanish}&key={api_key}"
query_french = f"{url}{french}&key={api_key}"
query_chinese = f"{url}{chinese}&key={api_key}"

# %%
#We now send API requests to the census for county data for three languages - English, French, and Chinese

response_f = requests.get(query_french).json()
response_s = requests.get(query_spanish).json()
response_c = requests.get(query_chinese).json()

#Formatting those responses into dataframes 

df_french = pd.DataFrame(response_f)
df_spanish = pd.DataFrame(response_s)
df_chinese = pd.DataFrame(response_c)

#get rid of the default headings (the columns are automatically entitled 1,2,3 etc)
df_french.columns = df_french.iloc[0]
df_french = df_french.drop(df_french.index[0])

df_spanish.columns = df_spanish.iloc[0]
df_spanish = df_spanish.drop(df_spanish.index[0])

df_chinese.columns = df_chinese.iloc[0]
df_chinese = df_chinese.drop(df_chinese.index[0])

#Quick test that this has all worked so far. 
print(len(df_french))
df_french.head()
# Out:
# 155
# 0    EST LANLABEL                        NAME  LAN state county
# 1   1035   French  Anchorage Municipality, AK  620    02    020
# 2  10680   French         Maricopa County, AZ  620    04    013
# 3     85   French           Navajo County, AZ  620    04    017
# 4   3230   French             Pima County, AZ  620    04    019
# 5   6915   French          Alameda County, CA  620    06    001

# %%
#We need the total populations of each county as of 2013. This comes from a different API at the Census. 
#apparently I can't download all the counties in all the states at once (so I could just merge on FIPS code)
#so I ended up querying the API just for a list of the counties we're already looking at, one by one, using a "for" loop.
#this takes forever and I'm sorry. 

countypoplist = []

#Note that this uses the french dataframe as its source - that shouldn't make a difference (the county lists are the same for all languages surveyed)

for row in df_french.index:
    st = df_french.loc[row, 'state']
    print(st)
    cty = df_french.loc[row, 'county']
    print(cty)
    query_pop = f"https://api.census.gov/data/2013/pep/cty?get=STNAME,POP,CTYNAME&for=county:{cty}&in=state:{st}&DATE_=6&key={api_key}"
    response_pop = requests.get(query_pop).json()
    countypoplist.append(response_pop)

print(countypoplist)
# Out:
# 02
# 020
# 04
# 013
# 04
# 017
# 04
# 019
# 06
# 001
# 06
# 013
# 06
# 019
# 06
# 029
# 06
# 037
# 06
# 053
# 06
# 059
# 06
# 061
# 06
# 065
# 06
# 067
# 06
# 071
# 06
# 073
# 06
# 075
# 06
# 077
# 06
# 081
# 06
# 083
# 06
# 085
# 06
# 095
# 06
# 097
# 06
# 099
# 06
# 111
# 06
# 113
# 08
# 005
# 08
# 031
# 08
# 041
# 09
# 001
# 09
# 003
# 09
# 009
# 10
# 003
# 11
# 001
# 12
# 011
# 12
# 021
# 12
# 031
# 12
# 057
# 12
# 071
# 12
# 086
# 12
# 095
# 12
# 099
# 12
# 103
# 13
# 067
# 13
# 089
# 13
# 121
# 13
# 135
# 15
# 001
# 15
# 003
# 15
# 009
# 17
# 031
# 17
# 043
# 17
# 089
# 17
# 097
# 17
# 197
# 18
# 097
# 19
# 153
# 20
# 091
# 21
# 111
# 22
# 051
# 24
# 003
# 24
# 005
# 24
# 027
# 24
# 031
# 24
# 033
# 24
# 510
# 25
# 005
# 25
# 009
# 25
# 013
# 25
# 017
# 25
# 021
# 25
# 023
# 25
# 025
# 25
# 027
# 26
# 099
# 26
# 125
# 26
# 161
# 26
# 163
# 27
# 037
# 27
# 053
# 27
# 123
# 29
# 189
# 32
# 003
# 32
# 031
# 33
# 011
# 34
# 001
# 34
# 003
# 34
# 005
# 34
# 007
# 34
# 013
# 34
# 017
# 34
# 021
# 34
# 023
# 34
# 025
# 34
# 027
# 34
# 029
# 34
# 031
# 34
# 035
# 34
# 039
# 35
# 001
# 35
# 045
# 36
# 001
# 36
# 005
# 36
# 029
# 36
# 047
# 36
# 055
# 36
# 059
# 36
# 061
# 36
# 067
# 36
# 071
# 36
# 081
# 36
# 085
# 36
# 087
# 36
# 103
# 36
# 119
# 37
# 081
# 37
# 119
# 37
# 183
# 39
# 035
# 39
# 049
# 39
# 061
# 40
# 109
# 41
# 051
# 41
# 067
# 42
# 003
# 42
# 017
# 42
# 029
# 42
# 045
# 42
# 071
# 42
# 091
# 42
# 101
# 44
# 007
# 47
# 037
# 47
# 157
# 48
# 029
# 48
# 085
# 48
# 113
# 48
# 121
# 48
# 157
# 48
# 201
# 48
# 439
# 48
# 453
# 49
# 035
# 51
# 013
# 51
# 059
# 51
# 087
# 51
# 107
# 51
# 153
# 51
# 810
# 53
# 011
# 53
# 033
# 53
# 053
# 53
# 061
# 55
# 025
# 55
# 079
# [[['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['Alaska', '300950', 'Anchorage Municipality', '6', '02', '020']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['Arizona', '4009412', 'Maricopa County', '6', '04', '013']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['Arizona', '107322', 'Navajo County', '6', '04', '017']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['Arizona', '996554', 'Pima County', '6', '04', '019']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '1578891', 'Alameda County', '6', '06', '001']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '1094205', 'Contra Costa County', '6', '06', '013']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '955272', 'Fresno County', '6', '06', '019']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '864124', 'Kern County', '6', '06', '029']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '10017068', 'Los Angeles County', '6', '06', '037']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '428826', 'Monterey County', '6', '06', '053']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '3114363', 'Orange County', '6', '06', '059']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '367309', 'Placer County', '6', '06', '061']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '2292507', 'Riverside County', '6', '06', '065']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '1462131', 'Sacramento County', '6', '06', '067']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '2088371', 'San Bernardino County', '6', '06', '071']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '3211252', 'San Diego County', '6', '06', '073']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '837442', 'San Francisco County', '6', '06', '075']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '704379', 'San Joaquin County', '6', '06', '077']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '747373', 'San Mateo County', '6', '06', '081']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '435697', 'Santa Barbara County', '6', '06', '083']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '1862041', 'Santa Clara County', '6', '06', '085']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '424788', 'Solano County', '6', '06', '095']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '495025', 'Sonoma County', '6', '06', '097']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '525491', 'Stanislaus County', '6', '06', '099']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '839620', 'Ventura County', '6', '06', '111']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['California', '204593', 'Yolo County', '6', '06', '113']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['Colorado', '607070', 'Arapahoe County', '6', '08', '005']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['Colorado', '649495', 'Denver County', '6', '08', '031']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['Colorado', '655044', 'El Paso County', '6', '08', '041']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['Connecticut', '939904', 'Fairfield County', '6', '09', '001']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['Connecticut', '898272', 'Hartford County', '6', '09', '003']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'county'], ['Connecticut', '862287', 'New Haven County', '6', '09', '009']], [['STNAME', 'POP', 'CTYNAME', 'DATE_', 'state', 'cou ...

# %% [markdown]
# ### FIPS Codes
#
# * Every county in the United States has a unique five-digit identifier code that lets us look it up. It's called a FIPS Code.
# * We can use this unique FIPS code to merge several different datasets for the same geographic area.
# * Several of the following cells are concerned with generating FIPS codes for the different counties in the survey.
#     * The Census sends us the correct number but with the FIPS prefix for the state separate from the FIPS code for the county so they must be combined.

# %%
#this formats all the county populations into a dataframe to be merged below for county populations.


ctylist2 = [item[1] for item in countypoplist]

ctylist2_df = pd.DataFrame(ctylist2)

ctylist2_df.columns = ['STNAME', 'population', 'CTYNAME', 'DATE_', 'state', 'county']

ctylist2_df["fips"] = ctylist2_df["state"].map(str) + ctylist2_df["county"]

ctypop_df = ctylist2_df.drop(['STNAME', 'CTYNAME', 'DATE_', 'state', 'county'], axis=1)

ctypop_df.head()
# Out:
#   population   fips
# 0     300950  02020
# 1    4009412  04013
# 2     107322  04017
# 3     996554  04019
# 4    1578891  06001

# %%
#Now we're constructing FIPS codes in each of the language dataframes (this will allow us to merge on FIPS code in a second)

df_french["FIPS Code"] = df_french["state"].map(str) + df_french["county"]
df_spanish["FIPS Code"] = df_spanish["state"].map(str) + df_spanish["county"]
df_chinese["FIPS Code"] = df_chinese["state"].map(str) + df_chinese["county"]
#creates a FIPS Code column into each of the language dataframes

#https://stackoverflow.com/questions/19377969/combine-two-columns-of-text-in-dataframe-in-pandas-python


df_french.head()
# Out:
# 0    EST LANLABEL                        NAME  LAN state county FIPS Code
# 1   1035   French  Anchorage Municipality, AK  620    02    020     02020
# 2  10680   French         Maricopa County, AZ  620    04    013     04013
# 3     85   French           Navajo County, AZ  620    04    017     04017
# 4   3230   French             Pima County, AZ  620    04    019     04019
# 5   6915   French          Alameda County, CA  620    06    001     06001

# %%
#dropping unecessary columns from the dataframes in preparation for merging
#Keeping state and county codes for sorting list when shading counties
df_french2 = df_french
df_spanish2 = df_spanish
df_chinese2 = df_chinese

#del df_french['county']
df_french2 = df_french.rename(columns={"county":"county code","state":"state code"})
df_french2 = df_french2.rename(columns={'EST': 'no_french', 'LANLABEL': 'Language', 'NAME': 'county', 'FIPS Code': 'fips'})
#print(df_french2)
#del df_french['state']
del df_french2['LAN']
del df_french2['Language']

#del df_spanish['county']
#df_spanish2 = df_spanish.rename(columns={"county":"county code","state":"state code"})
df_spanish2 = df_spanish2.rename(columns={'EST': 'no_spanish', 'LANLABEL': 'Language', 'NAME': 'county', 'FIPS Code': 'fips'})
del df_spanish2['state']
del df_spanish2['LAN']
del df_spanish2['county']
del df_spanish2['Language']

#del df_chinese2['county']
#df_chinese2 = df_chinese.rename(columns={"county":"county code","state":"state code"})
df_chinese2 = df_chinese2.rename(columns={'EST': 'no_chinese', 'LANLABEL': 'Language', 'NAME': 'county', 'FIPS Code': 'fips'})
del df_chinese2['state']
del df_chinese2['LAN']
del df_chinese2['county']
del df_chinese2['Language']

#merge french and spanish into a master dataframe

df_all = df_french2.merge(df_spanish2, how = 'inner', on = 'fips')

# %%
#add chinese to the master dataframe

df_all = df_all.merge(df_chinese2, how='inner', on = 'fips')

# %%
#merging total county populations into the master dataframe

df_all = df_all.merge(ctypop_df, how='inner', on = 'fips')

df_all.head()
# Out:
#   no_french                      county state code county code   fips  \
# 0      1035  Anchorage Municipality, AK         02         020  02020
# 1     10680         Maricopa County, AZ         04         013  04013
# 2        85           Navajo County, AZ         04         017  04017
# 3      3230             Pima County, AZ         04         019  04019
# 4      6915          Alameda County, CA         06         001  06001
#
#   no_spanish no_chinese population
# 0      12635        740     300950
# 1     733630      13750    4009412
# 2       5885       None     107322
# 3     217115       4625     996554
# 4     241150      69165    1578891

# %%
#there are values for chinese that say 'none' and i"m trying to make them go away. 
#https://stackoverflow.com/questions/23743460/replace-none-with-nan-in-pandas-dataframe
df_all['no_chinese'].replace(to_replace=[None], value=[0], inplace=True)

#turns out all the numbers are still set as strings so we're setting them to integers...
df_all['no_spanish'] = df_all['no_spanish'].astype(int)
df_all['no_french'] = df_all['no_french'].astype(int)
df_all['no_chinese'] = df_all['no_chinese'].astype(int)
df_all['population'] = df_all['population'].astype(int)

#and now we're calculating the percentages of the population that speak each language...
df_all['pct_spanish'] = (df_all['no_spanish']/df_all['population'])*100
df_all['pct_french'] = (df_all['no_french']/df_all['population'])*100
df_all['pct_chinese'] = (df_all['no_chinese']/df_all['population'])*100

df_all.head()
# Out:
#    no_french                      county state code county code   fips  \
# 0       1035  Anchorage Municipality, AK         02         020  02020
# 1      10680         Maricopa County, AZ         04         013  04013
# 2         85           Navajo County, AZ         04         017  04017
# 3       3230             Pima County, AZ         04         019  04019
# 4       6915          Alameda County, CA         06         001  06001
#
#    no_spanish  no_chinese  population  pct_spanish  pct_french  pct_chinese
# 0       12635         740      300950     4.198372    0.343911     0.245888
# 1      733630       13750     4009412    18.297696    0.266373     0.342943
# 2        5885           0      107322     5.483498    0.079201     0.000000
# 3      217115        4625      996554    21.786577    0.324117     0.464099
# 4      241150       69165     1578891    15.273379    0.437966     4.380606

# %%
#reorder the columns in a way that makes more sense. 

df_all = df_all[['fips', 'county', 'state code', 'county code', 'population', 'no_french', 'pct_french', 'no_spanish', 'pct_spanish', 'no_chinese', 'pct_chinese']]
df_all.sort_values(by=['state code', 'county'])
# Out:
#       fips                      county state code county code  population  \
# 0    02020  Anchorage Municipality, AK         02         020      300950
# 1    04013         Maricopa County, AZ         04         013     4009412
# 2    04017           Navajo County, AZ         04         017      107322
# 3    04019             Pima County, AZ         04         019      996554
# 4    06001          Alameda County, CA         06         001     1578891
# ..     ...                         ...        ...         ...         ...
# 150  53033             King County, WA         53         033     2044449
# 151  53053           Pierce County, WA         53         053      819743
# 152  53061        Snohomish County, WA         53         061      745913
# 153  55025             Dane County, WI         55         025      509939
# 154  55079        Milwaukee County, WI         55         079      956023
#
#      no_french  pct_french  no_spanish  pct_spanish  no_chinese  pct_chinese
# 0         1035    0.343911       12635     4.198372         740     0.245888
# 1        10680    0.266373      733630    18.297696       13750     0.342943
# 2           85    0.079201        5885     5.483498           0     0.000000
# 3         3230    0.324117      217115    21.786577        4625     0.464099
# 4         6915    0.437966      241150    15.273379       69165     4.380606
# ..         ...         ...         ...          ...         ...          ...
# 150      11955    0.584754      121930     5.963954       38030     1.860159
# 151       1825    0.222631       44005     5.368146        1665     0.203112
# 152       2205    0.295611       41660     5.585102        5065     0.679034
# 153       2050    0.402009       23715     4.650556        4430     0.868731
# 154       2420    0.253132       88015     9.206368        2360     0.246856
#
# [155 rows x 11 columns]

# %%
#export it all to a CSV called "langs by county" for use in the analysis portion. 

df_all.to_csv('langs_by_county.csv', index=False)

# %% [markdown]
# ## Collecting and cleaning US Census Data for all languages spoken in Cook County
#
# * This section of the notebook covers the second research question - how many language speakers are in cook county?
#
# _Note: Remember that only about 155 languages are covered by the Census and the rationale behind their selection doesn't make a ton of sense to us as outside observers._

# %%
#the language codes used by the census range from 600 to 999. I am setting up a "for" loop that will ping the API server for each of these 500 codes in turn.
#We'll then put the codes that return values into a DataFrame for subsequent use. 
#Be warned that this takes about five minutes to complete. 

numbers = np.arange(600,999)

langlist = []

for value in numbers:
    try: 
        line = requests.get(f"https://api.census.gov/data/2013/language?get=EST,LANLABEL,LAN39&for=county:031&in=state:17&LAN={value}&key={api_key}").json()
        print(line)
        langlist.append(line)
    except:
        print(f"No response from server for {value}")

#These are some quick formats to the dataframe. 
        
langlist = [item[1] for item in langlist]

df_cook = pd.DataFrame(langlist, columns = ["Speakers", "Language", "Lang_39", "Lang_Code", "State", "County"])

df_cook.head()
# Out:
# No response from server for 600
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['555', 'Jamaican Creole', '00', '601', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Krio', '00', '602', '17', '031']]
# No response from server for 603
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['50', 'Pidgin', '00', '604', '17', '031']]
# No response from server for 605
# No response from server for 606
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['17305', 'German', '00', '607', '17', '031']]
# No response from server for 608
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['1154', 'Yiddish', '07', '609', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['1550', 'Dutch', '00', '610', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['115', 'Afrikaans', '00', '611', '17', '031']]
# No response from server for 612
# No response from server for 613
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['930', 'Swedish', '00', '614', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['325', 'Danish', '00', '615', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['260', 'Norwegian', '00', '616', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['25', 'Icelandic', '00', '617', '17', '031']]
# No response from server for 618
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['22651', 'Italian', '04', '619', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['18265', 'French', '00', '620', '17', '031']]
# No response from server for 621
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['315', 'Patois', '00', '622', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['4098', 'French Creole', '03', '623', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Cajun', '00', '624', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['991495', 'Spanish', '00', '625', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Catalonian', '00', '626', '17', '031']]
# No response from server for 627
# No response from server for 628
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['3180', 'Portuguese', '00', '629', '17', '031']]
# No response from server for 630
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['12290', 'Romanian', '00', '631', '17', '031']]
# No response from server for 632
# No response from server for 633
# No response from server for 634
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['1150', 'Irish Gaelic', '00', '635', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['75', 'Scottic Gaelic', '00', '636', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['23031', 'Greek', '10', '637', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['5055', 'Albanian', '00', '638', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['26215', 'Russian', '11', '639', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['40', 'Bielorussian', '00', '640', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['9475', 'Ukrainian', '00', '641', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['1850', 'Czech', '00', '642', '17', '031']]
# No response from server for 643
# No response from server for 644
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['141431', 'Polish', '12', '645', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['1445', 'Slovak', '00', '646', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['8420', 'Bulgarian', '00', '647', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['855', 'Macedonian', '00', '648', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['9295', 'Serbocroatian', '00', '649', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['3335', 'Croatian', '00', '650', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['9985', 'Serbian', '00', '651', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['245', 'Slovene', '00', '652', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['6970', 'Lithuanian', '00', '653', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['945', 'Latvian', '00', '654', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['2222', 'Armenian', '15', '655', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['3342', 'Persian', '16', '656', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['100', 'Pashto', '00', '657', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['95', 'Kurdish', '00', '658', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['30', 'Balochi', '00', '659', '17', '031']]
# No response from server for 660
# No response from server for 661
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['995', 'India n.e.c.', '00', '662', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['20180', 'Hindi', '17', '663', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['3545', 'Bengali', '00', '664', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['2525', 'Panjabi', '00', '665', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['1770', 'Marathi', '00', '666', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['23250', 'Gujarati', '18', '667', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Bihari', '00', '668', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Rajasthani', '00', '669', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['185', 'Oriya', '00', '670', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['22583', 'Urdu', '19', '671', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['95', 'Assamese', '00', '672', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['65', 'Kashmiri', '00', '673', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['1580', 'Nepali', '00', '674', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['245', 'Sindhi', '00', '675', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['165', 'Pakistan n.e.c.', '00', '676', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['200', 'Sinhalese', '00', '677', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['90', 'Romany', '00', '678', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['265', 'Finnish', '00', '679', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['105', 'Estonian', '00', '680', '17', '031']]
# No response from server for 681
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['1518', 'Hungarian', '35', '682', '17', '031']]
# No response from server for 683
# No response from server for 684
# No response from server for 685
# No response from server for 686
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['105', 'Kirghiz', '00', '687', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Karachay', '00', '688', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['240', 'Uighur', '00', '689', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['55', 'Azerbaijani', '00', '690', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['2465', 'Turkish', '00', '691', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Turkmen', '00', '692', '17', '031']]
# No response from server for 693
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['1655', 'Mongolian', '00', '694', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['105', 'Tungus', '00', '695', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['115', 'Caucasian', '00', '696', '17', '031']]
# No response from server for 697
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Dravidian', '00', '698', '17', '031']]
# No response from server for 699
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['35', 'Gondi', '00', '700', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['5275', 'Telugu', '00', '701', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['1140', 'Kannada', '00', '702', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['8530', 'Malayalam', '00', '703', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['4220', 'Tamil', '00', '704', '17', '031']]
# No response from server for 705
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Munda', '00', '706', '17', '031']]
# No response from server for 707
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['39185', 'Chinese', '00', '708', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Hakka', '00', '709', '17', '031']]
# No response from server for 710
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['11355', 'Cantonese', '00', '711', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['5970', 'Mandarin', '00', '712', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Fuchow', '00', '713', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['1010', 'Formosan', '00', '714', '17', '031']]
# No response from server for 715
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['240', 'Tibetan', '00', '716', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['1255', 'Burmese', '00', '717', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['70', 'Karen', '00', '718', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Kachin', '00', '719', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['4734', 'Thai', '27', '720', '17', '031']]
# No response from server for 721
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['55', 'Hmong', '26', '722', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['7432', 'Japanese', '23', '723', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['31321', 'Korean', '24', '724', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['1009', 'Laotian', '28', '725', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['2103', 'Mon-Khmer, Cambodian', '25', '726', '17', '031']]
# No response from server for 727
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['10905', 'Vietnamese', '29', '728', '17', '031']]
# No response from server for 729
# No response from server for 730
# No response from server for 731
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['545', 'Indonesian', '00', '732', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Achinese', '00', '733', '17', '031']]
# No response from server for 734
# No response from server for 735
# No response from server for 736
# No response from server for 737
# No response from server for 738
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['810', 'Malay', '00', '739', '17', '031']]
# No response from server for 740
# No response from server for 741
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['46510', 'Tagalog', '31', '742', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['580', 'Bisayan', '00', '743', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['485', 'Sebuano', '00', '744', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['40', 'Pangasinan', '00', '745', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['225', 'Ilocano', '00', '746', '17', '031']]
# No response from server for 747
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['110', 'Pampangan', '00', '748', '17', '031']]
# No response from server for 749
# No response from server for 750
# No response from server for 751
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['240', 'Chamorro', '00', '752', '17', '031']]
# No response from server for 753
# No response from server for 754
# No response from server for 755
# No response from server for 756
# No response from server for 757
# No response from server for 758
# No response from server for 759
# No response from server for 760
# No response from server for 761
# No response from server for 762
# No response from server for 763
# No response from server for 764
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Melanesian', '00', '765', '17', '031']]
# No response from server for 766
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Samoan', '00', '767', '17', '031']]
# No response from server for 768
# No response from server for 769
# No response from server for 770
# No response from server for 771
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Marquesan', '00', '772', '17', '031']]
# No response from server for 773
# No response from server for 774
# No response from server for 775
# No response from server for 776
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['41460', 'Arabic', '36', '777', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['4843', 'Hebrew', '37', '778', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['13265', 'Syriac', '00', '779', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['3185', 'Amharic', '00', '780', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Berber', '00', '781', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['395', 'Chadic', '00', '782', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['1065', 'Cushite', '00', '783', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['385', 'Sudanic', '00', '784', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['40', 'Nilotic', '00', '785', '17', '031']]
# No response from server for 786
# No response from server for 787
# No response from server for 788
# No response from server for 789
# No response from server for 790
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['955', 'Swahili', '00', '791', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['875', 'Bantu', '00', '792', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['280', 'Mande', '00', '793', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['400', 'Fulani', '00', '794', '17', '031']]
# No response from server for 795
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['12400', 'Kru, Ibo, Yoruba', '00', '796', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['165', 'Efik', '00', '797', '17', '031']]
# No response from server for 798
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['465', 'African', '00', '799', '17', '031']]
# No response from server for 800
# No response from server for 801
# No response from server for 802
# No response from server for 803
# No response from server for 804
# No response from server for 805
# No response from server for 806
# No response from server for 807
# No response from server for 808
# No response from server for 809
# No response from server for 810
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['35', 'Cree', '00', '811', '17', '031']]
# No response from server for 812
# No response from server for 813
# No response from server for 814
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['20', 'Menomini', '00', '815', '17', '031']]
# No response from server for 816
# No response from server for 817
# No response from server for 818
# No response from server for 819
# No response from server for 820
# No response from server for 821
# No response from server for 822
# No response from server for 823
# No response from server for 824
# No response from server for 825
# No response from server for 826
# No response from server for 827
# No response from server for 828
# No response from server for 829
# No response from server for 830
# No response from server for 831
# No response from server for 832
# No response from server for 833
# No response from server for 834
# No response from server for 835
# No response from server for 836
# No response from server for 837
# No response from server for 838
# No response from server for 839
# No response from server for 840
# No response from server for 841
# No response from server for 842
# No response from server for 843
# No response from server for 844
# No response from server for 845
# No response from server for 846
# No response from server for 847
# No response from server for 848
# No response from server for 849
# No response from server for 850
# No response from server for 851
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['35', 'Kuchin', '00', '852', '17', '031']]
# No response from server for 853
# No response from server for 854
# No response from server for 855
# No response from server for 856
# No response from server for 857
# No response from server for 858
# No response from server for 859
# No response from server for 860
# No response from server for 861
# No response from server for 862
# No response from server for 863
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['38', 'Navajo', '33', '864', '17', '031']]
# No response from server for 865
# No response from server for 866
# No response from server for 867
# No response from server for 868
# No response from server for 869
# No response from server for 870
# No response from server for 871
# No response from server for 872
# No response from server for 873
# No response from server for 874
# No response from server for 875
# No response from server for 876
# No response from server for 877
# No response from server for 878
# No response from server for 879
# No response from server for 880
# No response from server for 881
# No response from server for 882
# No response from server for 883
# No response from server for 884
# No response from server for 885
# No response from server for 886
# No response from server for 887
# No response from server for 888
# No response from server for 889
# No response from server for 890
# No response from server for 891
# No response from server for 892
# No response from server for 893
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Yuma', '00', '894', '17', '031']]
# No response from server for 895
# No response from server for 896
# No response from server for 897
# No response from server for 898
# No response from server for 899
# No response from server for 900
# No response from server for 901
# No response from server for 902
# No response from server for 903
# No response from server for 904
# No response from server for 905
# No response from server for 906
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['75', 'Dakota', '00', '907', '17', '031']]
# No response from server for 908
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Winnebago', '00', '909', '17', '031']]
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Kansa', '00', '910', '17', '031']]
# No response from server for 911
# No response from server for 912
# No response from server for 913
# No response from server for 914
# No response from server for 915
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Choctaw', '00', '916', '17', '031']]
# No response from server for 917
# No response from server for 918
# No response from server for 919
# No response from server for 920
# No response from server for 921
# No response from server for 922
# No response from server for 923
# No response from server for 924
# No response from server for 925
# No response from server for 926
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Oneida', '00', '927', '17', '031']]
# No response from server for 928
# No response from server for 929
# No response from server for 930
# No response from server for 931
# No response from server for 932
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Cherokee', '00', '933', '17', '031']]
# No response from server for 934
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Caddo', '00', '935', '17', '031']]
# No response from server for 936
# No response from server for 937
# No response from server for 938
# No response from server for 939
# No response from server for 940
# No response from server for 941
# No response from server for 942
# No response from server for 943
# No response from server for 944
# No response from server for 945
# No response from server for 946
# No response from server for 947
# No response from server for 948
# No response from server for 949
# No response from server for 950
# No response from server for 951
# No response from server for 952
# No response from server for 953
# No response from server for 954
# No response from server for 955
# No response from server for 956
# No response from server for 957
# No response from server for 958
# No response from server for 959
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Tiwa', '00', '960', '17', '031']]
# No response from server for 961
# No response from server for 962
# No response from server for 963
# No response from server for 964
# No response from server for 965
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'American Indian', '00', '966', '17', '031']]
# No response from server for 967
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], [None, 'Mayan languages', '00', '968', '17', '031']]
# No response from server for 969
# No response from server for 970
# No response from server for 971
# No response from server for 972
# No response from server for 973
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['175', 'Arawakian', '00', '974', '17', '031']]
# No response from server for 975
# No response from server for 976
# No response from server for 977
# No response from server for 978
# No response from server for 979
# No response from server for 980
# No response from server for 981
# No response from server for 982
# No response from server for 983
# No response from server for 984
# No response from server for 985
# No response from server for 986
# No response from server for 987
# No response from server for 988
# No response from server for 989
# No response from server for 990
# No response from server for 991
# No response from server for 992
# No response from server for 993
# No response from server for 994
# No response from server for 995
# [['EST', 'LANLABEL', 'LAN39', 'LAN', 'state', 'county'], ['50', 'Uncodable', '00', '996', '17', '031']]
# No response from server for 997
# No response from server for 998
#   Speakers         Language Lang_39 Lang_Code State County
# 0      555  Jamaican Creole      00       601    17    031
# 1     None             Krio      00       602    17    031
# 2       50           Pidgin      00       604    17    031
# 3    17305           German      00       607    17    031
# 4     1154          Yiddish      07       609    17    031

# %%
#This exports all the languages in Cook County to a CSV for use in the analysis program. 

df_cook.to_csv('cook_languages.csv', index=True)
