# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
import gmaps

# Census & gmaps API Keys
from config import (c_key)
c = Census(c_key)

# Configure gmaps
#gmaps.configure(api_key=gkey)

# %%
response = requests.get(f"https://api.census.gov/data/2013/language?get=EST,LANLABEL,NAME&for=county:*&LAN=625&LAN=712&key={c_key}").json()
response
# Out:
# [['EST', 'LANLABEL', 'NAME', 'LAN', 'state', 'county'],
#  ['12635', 'Spanish', 'Anchorage Municipality, AK', '625', '02', '020'],
#  ['95', 'Mandarin', 'Anchorage Municipality, AK', '712', '02', '020'],
#  ['733630', 'Spanish', 'Maricopa County, AZ', '625', '04', '013'],
#  ['3890', 'Mandarin', 'Maricopa County, AZ', '712', '04', '013'],
#  ['5885', 'Spanish', 'Navajo County, AZ', '625', '04', '017'],
#  [None, 'Mandarin', 'Navajo County, AZ', '712', '04', '017'],
#  ['217115', 'Spanish', 'Pima County, AZ', '625', '04', '019'],
#  ['955', 'Mandarin', 'Pima County, AZ', '712', '04', '019'],
#  ['241150', 'Spanish', 'Alameda County, CA', '625', '06', '001'],
#  ['17450', 'Mandarin', 'Alameda County, CA', '712', '06', '001'],
#  ['176075', 'Spanish', 'Contra Costa County, CA', '625', '06', '013'],
#  ['5860', 'Mandarin', 'Contra Costa County, CA', '712', '06', '013'],
#  ['286750', 'Spanish', 'Fresno County, CA', '625', '06', '019'],
# ...

# %%
languages_count = {}
for r in response[1:]:
    if r[1]:
        if r[1] in languages_count.keys():
            languages_count[r[1]] += int(r[0])
        else:
            languages_count[r[1]] = int(r[0])
languages_count
# Out:
# {'Spanish': 26489005, 'Mandarin': 434769}
